# %%
# %matplotlib ipympl

import matplotlib.pyplot as plt
import cv2
import numpy as np

a = np.load('/home/amax_djh/ysl/nerf-pytorch/logs/avt_data_glass_20230218_6_dis/testset_200000/000_depth.npy')
# a = plt.imread('/home/ai/codebase/draft/avt_data_glass_20230218_6_dis/testset_200000/007_dexdepth.png')
plt.imshow(a)
plt.show()

# show_pointcloud_from_depth(a, 1.2303659303290422)
# a = plt.imread(fpath)
# show_pointcloud_from_depth(a, None, 608.8029174804688)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
